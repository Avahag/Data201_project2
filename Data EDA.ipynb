# %%
import pandas as pd

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\ava

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pathlib import Path

# %%
file_path = Path('C:/Users/ava/Downloads/archive (67).zip')
data = pd.read_csv(file_path)

# %%
# the first rows
print(data.head())
# Out:
#    Employee_ID Employment_Type  Hours_Worked_Per_Week  Productivity_Score  \
# 0            1          Remote                     29                  75
# 1            2       In-Office                     45                  49
# 2            3          Remote                     34                  74
# 3            4          Remote                     25                  81
# 4            5          Remote                     50                  70
#
#    Well_Being_Score
# 0                78
# 1                47
# 2                89
# 3                84
# 4                74

# %%
# info on dataset 
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Employment_Type        1000 non-null   object
#  2   Hours_Worked_Per_Week  1000 non-null   int64
#  3   Productivity_Score     1000 non-null   int64
#  4   Well_Being_Score       1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB
# None

# %%
# summary statistics of data
print(data.describe())
# Out:
#        Employee_ID  Hours_Worked_Per_Week  Productivity_Score  \
# count  1000.000000            1000.000000         1000.000000
# mean    500.500000              39.720000           68.602000
# std     288.819436               8.042779           12.235494
# min       1.000000              16.000000           33.000000
# 25%     250.750000              34.750000           60.000000
# 50%     500.500000              40.000000           68.000000
# 75%     750.250000              45.000000           76.000000
# max    1000.000000              64.000000          112.000000
#
#        Well_Being_Score
# count       1000.000000
# mean          63.975000
# std           13.870572
# min           14.000000
# 25%           56.000000
# 50%           65.000000
# 75%           73.000000
# max          104.000000

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Employment_Type        1000 non-null   object
#  2   Hours_Worked_Per_Week  1000 non-null   int64
#  3   Productivity_Score     1000 non-null   int64
#  4   Well_Being_Score       1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB
# None

# %%
#convert categorical data to numeric for heatmap 
data_encoded=pd.get_dummies(data)
data_encoded
# Out:
#      Employee_ID  Hours_Worked_Per_Week  Productivity_Score  Well_Being_Score  \
# 0              1                     29                  75                78
# 1              2                     45                  49                47
# 2              3                     34                  74                89
# 3              4                     25                  81                84
# 4              5                     50                  70                74
# ..           ...                    ...                 ...               ...
# 995          996                     33                  88                82
# 996          997                     33                  88                73
# 997          998                     45                  74                61
# 998          999                     57                  50                52
# 999         1000                     34                  80                82
#
# ...

# %%
# checking for missing values 
missing_count = data.isnull().sum()
print(missing_count)
# Out:
# Employee_ID              0
# Employment_Type          0
# Hours_Worked_Per_Week    0
# Productivity_Score       0
# Well_Being_Score         0
# dtype: int64

# %%
# data is clean (no missing values)

# %%
# Visualize distributions
sns.boxplot(data['Hours_Worked_Per_Week'])
plt.show()

# %%
# Distribution of Productivity Score
sns.histplot(data['Productivity_Score'], kde=True)
plt.title('Distribution of Productivity Score')
plt.show()

# %%
correlation_matrix = data_encoded.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Employment_Type', y='Hours_Worked_Per_Week', data=data, palette='viridis')  
plt.title('Hours Worked Per Week by Employment Type')
plt.xlabel('Employment Type')
plt.ylabel('Hours Worked Per Week')
plt.show()
# Out:
# C:\Users\ava\AppData\Local\Temp\ipykernel_32636\4189670456.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Employment_Type', y='Hours_Worked_Per_Week', data=data, palette='viridis')

# %%
# Group analysis by employment type
plt.figure(figsize=(8, 6))
sns.boxplot(x='Employment_Type', y='Productivity_Score', data=data , palette='coolwarm')
plt.title('Productivity Score by Employment Type')
plt.show()
# Out:
# C:\Users\ava\AppData\Local\Temp\ipykernel_32636\1013768190.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Employment_Type', y='Productivity_Score', data=data , palette='coolwarm')
